# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Загружаем данные
data2016 = pd.read_csv('pred2016l.csv', sep = ',', engine = 'python')
data2017 = pd.read_csv('pred2017l.csv', sep = ',', engine = 'python')

# %%
# Out:
#        Open  High   Low  Close    HOD    LOD    HOY    LOY  VPOC  VPOC-1  \
# 0      0.06  0.00  0.10   0.04 -0.275  0.080 -0.555 -0.010  0.04    0.00
# 1     -0.02 -0.04  0.10   0.04 -0.270  0.085 -0.550 -0.005  0.00   -0.04
# 2      0.08 -0.06  0.10   0.00 -0.255  0.100 -0.535  0.010  0.04    0.06
# 3      0.12 -0.06  0.12   0.00 -0.230  0.125 -0.510  0.035  0.00    0.14
# 4      0.00 -0.02  0.10   0.04 -0.235  0.120 -0.515  0.030  0.04   -0.02
# 5     -0.02 -0.04  0.10   0.04 -0.445  0.025 -0.725 -0.180  0.04    0.02
# 6     -0.02 -0.04  0.10   0.04 -0.460  0.055 -0.740 -0.195  0.04   -0.08
# 7      0.06 -0.06  0.08   0.00 -0.500  0.035 -0.780 -0.235 -0.02    0.00
# 8      0.02 -0.06  0.04   0.00 -0.465  0.070 -0.745 -0.200 -0.02    0.12
# 9     -0.02 -0.02  0.10   0.04 -0.825  0.025 -1.000 -0.560  0.02   -0.06
# 10     0.08 -0.06  0.14   0.00 -0.790  0.060 -1.000 -0.525  0.08    0.16
# 11     0.06 -0.06  0.06   0.00 -0.735  0.115 -1.000 -0.470 -0.02    0.02
# ...

# %%
data2016
#data2017
#Выведем данные
# Out:
#        Open  High   Low  Close    HOD    LOD    HOY    LOY  VPOC  VPOC-1  \
# 0      0.06  0.00  0.10   0.04 -0.275  0.080 -0.555 -0.010  0.04    0.00
# 1     -0.02 -0.04  0.10   0.04 -0.270  0.085 -0.550 -0.005  0.00   -0.04
# 2      0.08 -0.06  0.10   0.00 -0.255  0.100 -0.535  0.010  0.04    0.06
# 3      0.12 -0.06  0.12   0.00 -0.230  0.125 -0.510  0.035  0.00    0.14
# 4      0.00 -0.02  0.10   0.04 -0.235  0.120 -0.515  0.030  0.04   -0.02
# 5     -0.02 -0.04  0.10   0.04 -0.445  0.025 -0.725 -0.180  0.04    0.02
# 6     -0.02 -0.04  0.10   0.04 -0.460  0.055 -0.740 -0.195  0.04   -0.08
# 7      0.06 -0.06  0.08   0.00 -0.500  0.035 -0.780 -0.235 -0.02    0.00
# 8      0.02 -0.06  0.04   0.00 -0.465  0.070 -0.745 -0.200 -0.02    0.12
# 9     -0.02 -0.02  0.10   0.04 -0.825  0.025 -1.000 -0.560  0.02   -0.06
# 10     0.08 -0.06  0.14   0.00 -0.790  0.060 -1.000 -0.525  0.08    0.16
# 11     0.06 -0.06  0.06   0.00 -0.735  0.115 -1.000 -0.470 -0.02    0.02
# ...

# %%
#Каждый набор данных составлен из строк.Каждая строка вышеприведенных таблиц представляет собой одно событие  
#   и содержит функции в момент запуска события.
print(data2016)
#print(data2017)
# Out:
#        Open  High   Low  Close    HOD    LOD    HOY    LOY  VPOC  VPOC-1  \
# 0      0.06  0.00  0.10   0.04 -0.275  0.080 -0.555 -0.010  0.04    0.00
# 1     -0.02 -0.04  0.10   0.04 -0.270  0.085 -0.550 -0.005  0.00   -0.04
# 2      0.08 -0.06  0.10   0.00 -0.255  0.100 -0.535  0.010  0.04    0.06
# 3      0.12 -0.06  0.12   0.00 -0.230  0.125 -0.510  0.035  0.00    0.14
# 4      0.00 -0.02  0.10   0.04 -0.235  0.120 -0.515  0.030  0.04   -0.02
# 5     -0.02 -0.04  0.10   0.04 -0.445  0.025 -0.725 -0.180  0.04    0.02
# 6     -0.02 -0.04  0.10   0.04 -0.460  0.055 -0.740 -0.195  0.04   -0.08
# 7      0.06 -0.06  0.08   0.00 -0.500  0.035 -0.780 -0.235 -0.02    0.00
# 8      0.02 -0.06  0.04   0.00 -0.465  0.070 -0.745 -0.200 -0.02    0.12
# 9     -0.02 -0.02  0.10   0.04 -0.825  0.025 -1.000 -0.560  0.02   -0.06
# 10     0.08 -0.06  0.14   0.00 -0.790  0.060 -1.000 -0.525  0.08    0.16
# 11     0.06 -0.06  0.06   0.00 -0.735  0.115 -1.000 -0.470 -0.02    0.02
# ...

# %%
#Выведем первые 5 строк таблиц
data2016.head()
#data2017.head()
# Out:
#    Open  High   Low  Close    HOD    LOD    HOY    LOY  VPOC  VPOC-1  LinReg  \
# 0  0.06  0.00  0.10   0.04 -0.275  0.080 -0.555 -0.010  0.04    0.00   -0.20
# 1 -0.02 -0.04  0.10   0.04 -0.270  0.085 -0.550 -0.005  0.00   -0.04   -0.16
# 2  0.08 -0.06  0.10   0.00 -0.255  0.100 -0.535  0.010  0.04    0.06   -0.10
# 3  0.12 -0.06  0.12   0.00 -0.230  0.125 -0.510  0.035  0.00    0.14    0.00
# 4  0.00 -0.02  0.10   0.04 -0.235  0.120 -0.515  0.030  0.04   -0.02    0.00
#
#    LinRegSlope  CumDelta  Ticks
# 0        -0.34      -139  -0.06
# 1        -0.18      -314  -0.06
# 2        -0.23        81  -0.10
# 3        -0.28       609   0.06
# 4        -0.20        85   0.14

# %%
#Выведем последние 5 строк таблиц
data2016.tail()
#data2017.tail()
# Out:
#        Open  High   Low  Close    HOD    LOD    HOY    LOY  VPOC  VPOC-1  \
# 12738 -0.26 -0.30  0.10   0.04 -0.450  0.025 -0.395 -0.185 -0.12   -0.30
# 12739  0.06  0.00  0.10   0.04 -0.385  0.110 -0.330 -0.120  0.04    0.02
# 12740  0.04  0.00  0.10   0.04 -0.380  0.115 -0.325 -0.115  0.02    0.06
# 12741  0.12 -0.06  0.20   0.00 -0.420  0.075 -0.365 -0.155  0.14    0.16
# 12742  0.04 -0.06  0.04   0.00 -0.355  0.140 -0.300 -0.090 -0.02    0.06
#
#        LinReg  LinRegSlope  CumDelta  Ticks
# 12738   -0.52        -0.64     -5694   0.06
# 12739    0.00        -0.58       957   0.02
# 12740    0.02        -0.57      1230  -0.02
# 12741    0.02        -0.61      7392  -0.18
# 12742    0.34        -0.32       612  -0.06

# %%
#Получим размеры данных
print(data2016.shape)
#print(data2017.shape)
# Out:
# (12743, 14)

# %%
#В таблице1 12743 строки и 14 столбцов
#В таблице2 2849 строки и 14 столбцов
#Выведем их типы данных
type(data2016)
#type(data2017)
# Out:
# pandas.core.frame.DataFrame

# %%
#Тип столбца Ticks
type(data2016['Ticks'])
# Out:
# pandas.core.series.Series

# %%
#Вывдем названия столбцов
print('\n'.join([x for x in data2016.columns]))
# Out:
# Open
# High
# Low
# Close
# HOD
# LOD
# HOY
# LOY
# VPOC
# VPOC-1
# LinReg
# LinRegSlope
# CumDelta
# Ticks

# %%
#посмотрим общую информацию по набору из файла 2017 года
data2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12743 entries, 0 to 12742
# Data columns (total 14 columns):
# Open           12743 non-null float64
# High           12743 non-null float64
# Low            12743 non-null float64
# Close          12743 non-null float64
# HOD            12743 non-null float64
# LOD            12743 non-null float64
# HOY            12743 non-null float64
# LOY            12743 non-null float64
# VPOC           12743 non-null float64
# VPOC-1         12743 non-null float64
# LinReg         12743 non-null float64
# LinRegSlope    12743 non-null float64
# CumDelta       12743 non-null int64
# Ticks          12743 non-null float64
# dtypes: float64(13), int64(1)
# memory usage: 1.4 MB

# %%
#посмотрим общую информацию по набору из файла 2016 года
data2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12743 entries, 0 to 12742
# Data columns (total 14 columns):
# Open           12743 non-null float64
# High           12743 non-null float64
# Low            12743 non-null float64
# Close          12743 non-null float64
# HOD            12743 non-null float64
# LOD            12743 non-null float64
# HOY            12743 non-null float64
# LOY            12743 non-null float64
# VPOC           12743 non-null float64
# VPOC-1         12743 non-null float64
# LinReg         12743 non-null float64
# LinRegSlope    12743 non-null float64
# CumDelta       12743 non-null int64
# Ticks          12743 non-null float64
# dtypes: float64(13), int64(1)
# memory usage: 1.4 MB

# %%
#Посмотрим основные статистические характеристики данных
#По количественным признакам:
data2016.describe()
# Out:
#                Open          High           Low         Close           HOD  \
# count  12743.000000  12743.000000  12743.000000  12743.000000  12743.000000
# mean       0.022398     -0.056196      0.093276      0.018190     -0.287802
# std        0.080470      0.045801      0.048663      0.021551      0.298861
# min       -0.560000     -0.560000      0.020000     -0.120000     -1.000000
# 25%        0.000000     -0.060000      0.060000      0.000000     -0.395000
# 50%        0.020000     -0.060000      0.100000      0.000000     -0.175000
# 75%        0.060000     -0.040000      0.100000      0.040000     -0.065000
# max        0.660000      0.020000      0.720000      0.220000      0.000000
#
#                 LOD           HOY           LOY          VPOC        VPOC-1  \
# count  12743.000000  12743.000000  12743.000000  12743.000000  12743.000000
# mean       0.243449     -0.374287      0.218468      0.006768      0.022588
# ...

# %%
data2016.describe(include = 'all')
# Out:
#                Open          High           Low         Close           HOD  \
# count  12743.000000  12743.000000  12743.000000  12743.000000  12743.000000
# mean       0.022398     -0.056196      0.093276      0.018190     -0.287802
# std        0.080470      0.045801      0.048663      0.021551      0.298861
# min       -0.560000     -0.560000      0.020000     -0.120000     -1.000000
# 25%        0.000000     -0.060000      0.060000      0.000000     -0.395000
# 50%        0.020000     -0.060000      0.100000      0.000000     -0.175000
# 75%        0.060000     -0.040000      0.100000      0.040000     -0.065000
# max        0.660000      0.020000      0.720000      0.220000      0.000000
#
#                 LOD           HOY           LOY          VPOC        VPOC-1  \
# count  12743.000000  12743.000000  12743.000000  12743.000000  12743.000000
# mean       0.243449     -0.374287      0.218468      0.006768      0.022588
# ...

# %%
#Вычислим корелляцию между признаками
data2016.corr()
# Out:
#                  Open      High       Low     Close       HOD       LOD  \
# Open         1.000000  0.530245  0.529059 -0.465504  0.069009  0.066304
# High         0.530245  1.000000  0.008379  0.089603  0.073986  0.010848
# Low          0.529059  0.008379  1.000000  0.107922 -0.014904  0.065611
# Close       -0.465504  0.089603  0.107922  1.000000 -0.042041 -0.016046
# HOD          0.069009  0.073986 -0.014904 -0.042041  1.000000 -0.038992
# LOD          0.066304  0.010848  0.065611 -0.016046 -0.038992  1.000000
# HOY          0.051219  0.059362 -0.025097 -0.041733  0.745360  0.059027
# LOY          0.034931  0.034081 -0.011640 -0.023917  0.705111  0.195099
# VPOC         0.327158  0.350548  0.486765  0.216531  0.000245  0.025097
# VPOC-1       0.828011  0.443557  0.438219 -0.391712  0.061180  0.065013
# LinReg       0.239154  0.123037  0.140873 -0.092496  0.080361  0.145988
# LinRegSlope  0.003048  0.000551  0.001171  0.002623  0.268882  0.359775
# ...

# %%
#Посмотрим корреляцию между столбцами, особенно высокая корреляция видна между столбцами (Open и VPOC-1)=0.828011;
# (HOY и HOD)=0.745360; (HOY и LOY)=0.722974; (LinRegSlope и LinReg)=0.605079;  (CumDelta и Open)=0.561554
data2016[((data2016["Close"]-data2016["Open"])) >0.1].corr() >0.9
# Out:
#               Open   High    Low  Close    HOD    LOD    HOY    LOY   VPOC  \
# Open          True   True  False  False  False  False  False  False  False
# High          True   True  False  False  False  False  False  False  False
# Low          False  False   True  False  False  False  False  False  False
# Close        False  False  False   True  False  False  False  False  False
# HOD          False  False  False  False   True  False  False  False  False
# LOD          False  False  False  False  False   True  False  False  False
# HOY          False  False  False  False  False  False   True  False  False
# LOY          False  False  False  False  False  False  False   True  False
# VPOC         False  False  False  False  False  False  False  False   True
# VPOC-1       False  False  False  False  False  False  False  False  False
# LinReg       False  False  False  False  False  False  False  False  False
# ...

# %%
data2016[(data2016["Close"]-data2016["Open"]) < 0].corr()
# Out:
#                  Open      High       Low     Close       HOD       LOD  \
# Open         1.000000 -0.062825  0.946567 -0.094195 -0.010654  0.095287
# High        -0.062825  1.000000 -0.008744  0.909591  0.028010 -0.019538
# Low          0.946567 -0.008744  1.000000 -0.046600 -0.012520  0.083244
# Close       -0.094195  0.909591 -0.046600  1.000000  0.045042 -0.020999
# HOD         -0.010654  0.028010 -0.012520  0.045042  1.000000 -0.030467
# LOD          0.095287 -0.019538  0.083244 -0.020999 -0.030467  1.000000
# HOY         -0.019297  0.018557 -0.021953  0.029322  0.741175  0.066483
# LOY         -0.009932  0.007257 -0.015999  0.020182  0.713787  0.193198
# VPOC         0.506625  0.201402  0.581225  0.138832 -0.015247  0.030171
# VPOC-1       0.754150 -0.054431  0.729472 -0.081964 -0.004363  0.070774
# LinReg       0.224031 -0.000939  0.195397 -0.018087  0.045022  0.177820
# LinRegSlope  0.014245  0.000976  0.000931 -0.013430  0.269279  0.372652
# ...

# %%
plt.plot(data2016['Open'], data2016['VPOC-1'], 'o', color = 'red', alpha = 0.6)
plt.xlabel('Open')
plt.ylabel('VPOC-1')
pass

# %%
from pandas.plotting import scatter_matrix 
scatter_matrix(data2016, alpha = .02, figsize = (14, 14), color='pink')
pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-68e49fdbe816> in <module>()
#       1 from pandas.plotting import scatter_matrix
# ----> 2 scatter_matrix(data2016, alpha = .02, figsize = (14, 14), color='pink')
#       3 pass
#
# NameError: name 'data2016' is not defined

# %% [markdown]
# ## Задача
# Показать максимальное значение прибыли max(Close-Open)

# %%
#Сделал вектор выгоды, выкинул Ticks, так как по таблицы корреляции видимо очень похоже с HOD. 

Set1=data2016['Open']
Set2=data2016['Close']
Profit=(Set2-Set1)
Profit.name='Profit'
data = data2016.drop(['Open','Close','Ticks'], axis = 1)
X=data
y=Profit
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 8920 3823

# %%
#Можем разбить достаточно большой сет 16 года, но так как у нас два ниже будем учить на 16 годе, а тестировать на 17

# %%
Set1=data2016['Open']
Set2=data2016['Close']
Profit=(Set2-Set1)
Profit.name='Profit'
data = data2016.drop(['Open','Close','Ticks'], axis = 1)
X_train=data
y_train=Profit

# %%
Set1=data2017['Open']
Set2=data2017['Close']
Profit1=(Set2-Set1)
Profit1.name='Profit'
data1 = data2017.drop(['Open','Close','Ticks'], axis = 1)
X_test=data1
y_test=Profit1
print(X_test.shape,X_train.shape)
# Out:
# (2849, 11) (12743, 11)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 4)
knn.set_params(n_neighbors=10)
knn.fit(X_train, y_train.astype('int'))
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#            weights='uniform')

# %%
knn
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print(err_train, err_test)

err_test = 1 - knn.score(X_test, y_test)
print(err_test)
# Out:
# 0.730204818332 0.891540891541
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-9a1d31620b8a> in <module>()
#       8 print(err_train, err_test)
#       9
# ---> 10 err_test = 1 - knn.score(X_test, y_test)
#      11 print(err_test)
#
# C:\LOL\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     348         """
#     349         from .metrics import accuracy_score
# --> 350         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     351
#     352
#
# C:\LOL\lib\site-packages\sklearn\metrics\classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     if y_type.startswith('multilabel'):
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-e5ec9f4d51f8> in <module>()
# ----> 1 err_test = 1 - knn.score(X_test, y_test)
#
# C:\LOL\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     348         """
#     349         from .metrics import accuracy_score
# --> 350         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     351
#     352
#
# C:\LOL\lib\site-packages\sklearn\metrics\classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     if y_type.startswith('multilabel'):
#     178         differing_labels = count_nonzero(y_true - y_pred, axis=1)
#
# ...
